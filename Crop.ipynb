# %%
import librosa
import numpy as np 
import pickle
import matplotlib.pyplot as plt
import os
from IPython.display import Audio

from pydub import AudioSegment

# %%
seperation_path = "output/You_Raise_me_Up/"
log = []

# log = pickle.load(open(seperation_path + "log.pkl", "rb"))

# %%
wav, rate = librosa.load(seperation_path + "vocals.wav")

# %%
start = 273
end = start+4.2
Audio(wav[int(start * rate):int(end * rate)], rate=rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
log.append([start, end, "can be"])

# %%
You raise me up, so I can stand on mountains
You raise me up to walk on stormy seas
I am strong when I am on your shoulders
You raise me up to more than I can be
You raise me up, so I can stand on mountains
You raise me up to walk on stormy seas
I am strong when I am on your shoulders
You raise me up to more than I can be
You raise me up to more than I can be

# %%
log
# Out:
# [[55, 57.8, 'When I am down'],
#  [58.3, 60.3, 'and oh my soul'],
#  [60.4, 62.4, 'so weary'],
#  [63, 66.3, 'When troubles come'],
#  [66.9, 71.0, 'and my heart burdened be'],
#  [72, 75, 'Then, I am still'],
#  [75.5, 77.5, 'and wait here'],
#  [77.5, 79.5, 'in the silence'],
#  [80.5, 82.9, 'Until you come'],
#  [83.4, 85.80000000000001, 'and sit awhile'],
#  [86.1, 88.5, 'with me'],
#  [89.2, 92.10000000000001, 'You raise me up'],
#  [92.55, 93.955, 'so I can'],
#  [93.955, 96.855, 'stand on mountains'],
#  [97.4, 100.7, 'You raise me up'],
#  [101.2, 102.52, 'to walk on'],
#  [102.52, 106.11999999999999, 'stormy seas'],
#  [106.8, 109.5, 'I am strong'],
#  [109.86, 111.91, 'when I am on'],
#  [111.92, 115.12, 'your shoulders'],
#  [115.5, 118.5, 'You raise me up'],
#  [118.5, 122.4, 'to more than I can be'],
#  [157.4, 159.95000000000002, 'You raise me up'],
#  [160.2, 165.2, 'so I can stand on mountains'],
#  [165.5, 168.5, 'You raise me up'],
#  [168.55, 173.75, 'to walk on stormy seas'],
#  [174.25, 182.45, 'I am strong when I am on your shoulders'],
#  [182.6, 185.6, 'You raise me up'],
#  [185.6, 189.7, 'to more than I can be'],
#  [194.8, 197.3, 'You raise me up'],
#  [197.7, 202.29999999999998, 'so I can stand on mountains'],
#  [203.1, 205.6, 'You raise me up'],
#  [206, 209.5, 'to walk on stormy seas'],
#  [211.5, 214.1, 'I am strong'],
#  [214.3, 218.9, 'when I am on your shoulders'],
#  [219.5, 222.0, 'You raise me up'],
#  [222.5, 226.5, 'to more than I can be'],
#  [227.5, 230.0, 'You raise me up'],
#  [230.5, 234.6, 'so I can stand on mountains'],
#  [235.7, 238.2, 'You raise me up'],
#  [238.7, 241.89999999999998, 'to walk on stormy seas'],
#  [244, 246.5, 'I am strong'],
#  [246.8, 251.8, 'when I am on your shoulders'],
#  [252, 254.3, 'You raise me up'],
#  [254.7, 259.4, 'to more than I can be'],
#  [263, 267.7, 'You raise me up'],
#  [268.4, 272.59999999999997, 'to more than I'],
#  [273, 277.2, 'can be']]

# %%
pickle.dump(log, open(seperation_path + "log.pkl", "wb"))

# %%
def generate_music_list(wav, rate, seperation_path, log, path_name="test/", file_name="file_list.txt"):
    if not os.path.exists(seperation_path + path_name):
        os.makedirs(seperation_path + path_name)
    f = open(seperation_path + path_name + "file_list.txt", "w+")
    for i, l in enumerate(log):
        data = wav[int(float(l[0]) * rate):int(float(l[1]) * rate)]
        librosa.output.write_wav(seperation_path + path_name + str(i) + ".wav", data, rate)
        f.write("data/{}{}.wav|{}|1\n".format(path_name, str(i), str(l[2])))
    f.close()

# %%
generate_music_list(wav, rate, seperation_path, log, path_name="You_Raise_me_Up/", file_name="file_list.txt")

# %% [markdown]
# ## Compose

# %%
log = pickle.load(open(seperation_path + "log.pkl", "rb"))

# %%
wav_new = np.zeros(int((log[-1][1]+3) * rate), dtype=np.float32)

# %%
for i, l in enumerate(log):
    wav_temp, _ = librosa.load(seperation_path + "gen/{}.wav".format(i))
    wav_new[int(l[0] * rate):int(l[0] * rate)+len(wav_temp)] = wav_temp

# %%
accompaniment, rate = librosa.load(seperation_path + "accompaniment.wav")

# %%
com = wav_new + accompaniment[:len(wav_new)]

# %%
librosa.output.write_wav(seperation_path + "com.wav", com, rate)

# %%
sound = AudioSegment.from_wav(seperation_path + "com.wav")

sound.export(seperation_path + "com.mp3", format='mp3')
# Out:
# <_io.BufferedRandom name='output/You_Raise_me_Up/com.mp3'>
