# %%
# !spleeter separate -i songs/You_Raise_Me_Up.webm -o output/
# Out:
# INFO:spleeter:File output/You_Raise_Me_Up/vocals.wav written succesfully
# INFO:spleeter:File output/You_Raise_Me_Up/accompaniment.wav written succesfully

# %%
import librosa
import numpy as np 
import matplotlib.pyplot as plt

from pydub import AudioSegment

# %%
sound_name = "ole_guitar_s"

sound = AudioSegment.from_wav("output/" + sound_name + "/accompaniment.wav")
sound.export("output/" + sound_name + "/accompaniment.mp3", format='mp3')

sound = AudioSegment.from_wav("output/" + sound_name + "/vocals.wav")
sound.export("output/" + sound_name + "/vocals.mp3", format='mp3')
# Out:
# <_io.BufferedRandom name='output/ole_guitar_s/vocals.mp3'>

# %%
# wav, rate = librosa.load("songs/ole_guitar_s.m4a")
wav, rate = librosa.load("ole_google.m4a")

# plt.figure(figsize=(5,3), dpi=100)

plt.figure(figsize=(20,3), dpi=100)
ax = plt.gca()
ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
plt.plot(wav)
# Out:
# /Users/jojo/opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
