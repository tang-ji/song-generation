# %%
from scipy.io import wavfile
from glob import glob
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
import pandas as pd
import librosa
# %matplotlib inline

# %%
# wave, rate = librosa.load("output/Ole/sample4.wav")
# wave, rate = librosa.load("output/Ole/audio_stereo.wav")
wave, rate = librosa.load("output/Ole_guitar/sample3.wav")
wave
# Out:
# array([-1.1681767e-05, -1.5569631e-05, -2.5848663e-05, ...,
#         3.1903583e-05,  2.6048922e-03,  2.9164283e-03], dtype=float32)

# %%
plt.plot(wave)

# %%
yin = compute_yin(wave, rate, w_len=256, w_step=128, f0_min=100, f0_max=1000)

# %%
plt.plot(yin[3], yin[0])

# %%
rate_list = yin[0]
time_list = yin[3]

for i, t in enumerate(time_list):
    print(t, rate_list[i])
# Out:
# 0.0 107.5609756097561
# 0.005804988662131519 0.0
# 0.011609977324263039 0.0
# 0.017414965986394557 0.0
# 0.023219954648526078 108.08823529411765
# 0.029024943310657598 103.52112676056338
# 0.034829931972789115 0.0
# 0.040634920634920635 0.0
# 0.046439909297052155 0.0
# 0.052244897959183675 0.0
# 0.058049886621315196 0.0
# 0.06385487528344672 109.70149253731343
# 0.06965986394557823 0.0
# 0.07546485260770976 0.0
# 0.08126984126984127 0.0
# 0.08707482993197278 100.68493150684931
# 0.09287981859410431 0.0
# 0.09868480725623582 105.50239234449761
# 0.10448979591836735 118.54838709677419
# 0.11029478458049886 0.0
# 0.11609977324263039 108.62068965517241
# 0.1219047619047619 116.66666666666667
# 0.12770975056689343 100.68493150684931
# 0.13351473922902493 0.0
# 0.13931972789115646 0.0
# 0.14512471655328799 100.68493150684931
# 0.1509297052154195 0.0
# 0.156734693877551 0.0
# 0.16253968253968254 0.0
# 0.16834467120181407 170.93023255813952
# 0.17414965986394557 168.3206106870229
# ...

# %%
386.8421052631579/155.28169014084506
# Out:
# 2.491228070175439

# %%
rate_list = yin[0]
time_list = yin[3]

for i, t in enumerate(time_list):
    print(t, rate_list[i])
# Out:
# 0.0 0.0
# 0.011609977324263039 0.0
# 0.023219954648526078 0.0
# 0.034829931972789115 0.0
# 0.046439909297052155 0.0
# 0.058049886621315196 0.0
# 0.06965986394557823 0.0
# 0.08126984126984127 0.0
# 0.09287981859410431 0.0
# 0.10448979591836735 0.0
# 0.11609977324263039 0.0
# 0.12770975056689343 0.0
# 0.13931972789115646 501.1363636363636
# 0.1509297052154195 501.1363636363636
# 0.16253968253968254 501.1363636363636
# 0.17414965986394557 501.1363636363636
# 0.18575963718820862 501.1363636363636
# 0.19736961451247165 501.1363636363636
# 0.2089795918367347 501.1363636363636
# 0.22058956916099773 501.1363636363636
# 0.23219954648526078 512.7906976744187
# 0.2438095238095238 512.7906976744187
# 0.25541950113378686 512.7906976744187
# 0.26702947845804986 512.7906976744187
# 0.2786394557823129 501.1363636363636
# 0.29024943310657597 501.1363636363636
# 0.301859410430839 501.1363636363636
# 0.313469387755102 501.1363636363636
# 0.3250793650793651 501.1363636363636
# 0.33668934240362813 0.0
# ...
